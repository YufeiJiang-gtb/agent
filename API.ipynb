# %%
from openai import OpenAI

# 初始化客户端
client = OpenAI(
    api_key="sk-09966b765d0b4bcb80f8f11d0143075f",  # 替换成你的 API Key
    base_url="https://api.deepseek.com"  # 注意这里是 DeepSeek 的地址
)

# 发起对话请求
def chat_with_deepseek(prompt):
    response = client.chat.completions.create(
        model="deepseek-flash",  # 模型名就用这个
        messages=[
            {"role": "system", "content": "你是一个专业的生物信息学助手。。"},
            {"role": "user", "content": prompt}
        ],
        stream=False  # 先不要用流式输出，方便调试
    )   
    # 打印回复
    print(response.choices[0].message.content)

if __name__ == '__main__':
    chat_with_deepseek('请简单解释一下单细胞转录组测序概念。')
# Out:
# 喵喵喵，喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵喵
